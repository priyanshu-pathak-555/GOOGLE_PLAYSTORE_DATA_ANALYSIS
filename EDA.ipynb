# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Taking overview of Dataset

# %%
df  = pd.read_csv('C:/Users/priya/OneDrive/Desktop/PROIECT_PROJECT/EDA_GOOGLEPLAYSTORE_DATA/googleplaystore (1).csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# App                  1
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# # Observation
# The dataset has missing values

# %%
## Cleaning dataset

# %%
df = df.dropna(how='all')

# %%
df.shape
# Out:
# (10841, 13)

# %%
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
sns.distplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.boxplot(df['Rating'])
# Out:
# <Axes: ylabel='Rating'>

# %%
np.mean(df['Rating'])
# Out:
# np.float64(4.193338315362443)

# %%
df['Rating']=	df['Rating'].fillna(np.mean(df['Rating']))

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'],
#       shape=(6002,), dtype=object)

# %%
df['Reviews'].str.isnumeric().sum()
# Out:
# np.int64(10840)

# %%
df[~df['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
def convert_reviews(x):
    x = str(x)
    if 'M' in x:
        return float(x.replace('M', '')) * 1_000_000
    elif 'K' in x:
        return float(x.replace('K', '')) * 1_000
    else:
        return float(x)

df['Reviews'] = df['Reviews'].apply(convert_reviews).astype(int)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '1,000+',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %%
def convert_to_kb(size):
    if 'M' in size:
        mb_value = size.split('M')[0]
        kb_value = float(mb_value)*1024
        kb_value = str(f'{kb_value}k')
        return kb_value
    else:
        return size

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '1,000+',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %%
df['Size'] = df['Size'].apply(convert_to_kb)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews      Size     Installs  Type Price Content Rating  \
# 0      159  19456.0k      10,000+  Free     0       Everyone
# 1      967  14336.0k     500,000+  Free     0       Everyone
# 2    87510   8908.8k   5,000,000+  Free     0       Everyone
# 3   215644  25600.0k  50,000,000+  Free     0           Teen
# 4      967   2867.2k     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['Size'] = df['Size'].str.replace('k','')
df['Size'].dtypes
# Out:
# dtype('O')

# %%
df['Size'].unique()
# Out:
# array(['19456.0', '14336.0', '8908.8', '25600.0', '2867.2', '5734.4',
#        '29696.0', '33792.0', '3174.4', '28672.0', '12288.0', '20480.0',
#        '21504.0', '37888.0', '2764.8', '5632.0', '17408.0', '39936.0',
#        '31744.0', '4300.8', '7168.0', '23552.0', '6144.0', '6246.4',
#        '4710.4', '9420.8', '5324.8', '11264.0', '24576.0',
#        'Varies with device', '9625.6', '15360.0', '10240.0', '1228.8',
#        '26624.0', '8192.0', '8089.6', '57344.0', '58368.0', '35840.0',
#        '55296.0', '201', '3686.4', '5836.8', '8806.4', '2457.6',
#        '27648.0', '2560.0', '16384.0', '3481.6', '9113.6', '3993.6',
#        '2969.6', '38912.0', '32768.0', '5529.6', '18432.0', '1126.4',
#        '2252.8', '4608.0', '10035.2', '53248.0', '9216.0', '6860.8',
#        '30720.0', '2662.4', '7270.4', '3788.8', '22528.0', '7577.6',
#        '6553.6', '3276.8', '8396.8', '10137.6', '5017.6', '9728.0',
#        '5120.0', '6041.6', '13312.0', '74752.0', '6963.2', '3584.0',
#        '4096.0', '2355.2', '7372.8', '2150.4', '43008.0', '7475.2',
#        '9318.4', '56320.0', '23', '6656.0', '1536.0', '7680.0', '52224.0',
#        '41984.0', '49152.0', '8704.0', '47104.0', '8499.2', '4403.2',
#        '4812.8', '3379.2', '40960.0', '7987.2', '9011.2', '6758.4',
#        '5222.4', '62464.0', '67584.0', '79', '8601.6', '118', '45056.0',
#        '695', '1638.4', '6348.8', '18', '54272.0', '1433.6', '3072.0',
#        '5939.2', '3891.2', '9830.4', '46080.0', '64512.0', '50176.0',
#        '78848.0', '4505.6', '4915.2', '71680.0', '7065.6', '9523.2',
#        '8294.4', '36864.0', '86016.0', '99328.0', '2048.0', '1945.6',
#        '1843.2', '5427.2', '48128.0', '556', '526', '77824.0', '7782.4',
#        '60416.0', '9932.8', '79872.0', '73728.0', '44032.0', '7884.8',
#        '6451.2', '334', '34816.0', '95232.0', '66560.0', '80896.0',
#        '102400.0', '59392.0', '51200.0', '69632.0', '65536.0', '68608.0',
#        '61440.0', '96256.0', '232', '101376.0', '624', '97280.0', '8.5',
#        '41', '292', '11', '81920.0', '1740.8', '75776.0', '63488.0',
#        '70656.0', '76800.0', '100352.0', '87040.0', '83968.0', '98304.0',
#        '89088.0', '72704.0', '88064.0', '93184.0', '82944.0', '94208.0',
#        '84992.0', '90112.0', '704', '862', '899', '378', '266', '375',
#        '1331.2', '975', '980', '4198.4', '91136.0', '696', '544', '525',
#        '920', '779', '853', '720', '713', '772', '318', '58', '241',
#        '196', '857', '51', '953', '865', '251', '930', '540', '313',
#        '746', '203', '26', '314', '239', '371', '220', '730', '756', '91',
#        '293', '17', '74', '14', '317', '78', '924', '902', '818', '81',
#        '939', '169', '45', '475', '965', '92160.0', '545', '61', '283',
#        '655', '714', '93', '872', '121', '322', '1024.0', '976', '172',
#        '238', '549', '206', '954', '444', '717', '210', '609', '308',
#        '705', '306', '904', '473', '175', '350', '383', '454', '421',
#        '70', '812', '442', '842', '417', '412', '459', '478', '335',
#        '782', '721', '430', '429', '192', '200', '460', '728', '496',
#        '816', '414', '506', '887', '613', '243', '569', '778', '683',
#        '592', '319', '186', '840', '647', '191', '373', '437', '598',
#        '716', '585', '982', '222', '219', '55', '948', '323', '691',
#        '511', '951', '963', '25', '554', '351', '27', '82', '208', '913',
#        '514', '551', '29', '103', '898', '743', '116', '153', '209',
#        '353', '499', '173', '597', '809', '122', '411', '400', '801',
#        '787', '237', '50', '643', '986', '97', '516', '837', '780', '961',
#        '269', '20', '498', '600', '749', '642', '881', '72', '656', '601',
#        '221', '228', '108', '940', '176', '33', '663', '34', '942', '259',
#        '164', '458', '245', '629', '28', '288', '775', '785', '636',
#        '916', '994', '309', '485', '914', '903', '608', '500', '54',
#        '562', '847', '957', '688', '811', '270', '48', '329', '523',
#        '921', '874', '981', '784', '280', '24', '518', '754', '892',
#        '154', '860', '364', '387', '626', '161', '879', '39', '970',
#        '170', '141', '160', '144', '143', '190', '376', '193', '246',
#        '73', '658', '992', '253', '420', '404', '1,000+', '470', '226',
#        '240', '89', '234', '257', '861', '467', '157', '44', '676', '67',
#        '552', '885', '1020', '582', '619'], dtype=object)

# %%
import numpy as np

df['Size'] = df['Size'].replace('Varies with device', np.nan)
df['Size'] = df['Size'].replace('1,000+','1000')
df['Size'] = df['Size'].astype('float')

# %%
df['Size'].isnull().sum()
# Out:
# np.int64(1695)

# %%
sns.distplot(df['Size'], kde =True)
# Out:
# <Axes: xlabel='Size', ylabel='Density'>

# %%
sns.boxplot(df['Size'])
# Out:
# <Axes: ylabel='Size'>

# %%
median_size	=	df['Size'].median()
df['Size']	=	df['Size'].fillna(median_size)

# %%
df['Size'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size     Installs  Type Price Content Rating  \
# 0      159  19456.0      10,000+  Free     0       Everyone
# 1      967  14336.0     500,000+  Free     0       Everyone
# 2    87510   8908.8   5,000,000+  Free     0       Everyone
# 3   215644  25600.0  50,000,000+  Free     0           Teen
# 4      967   2867.2     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04'], dtype=object)

# %%
chars_to_remove	=	['+',',','$']
columns_to_clean = ['Installs','Price']
for item in chars_to_remove:
    for columns in columns_to_clean:
        df[columns] = df[columns].str.replace(item,'')

# %%
df['Price'] =df['Price'].replace('Everyone',0)

# %%
df['Price']	=	df['Price'].astype(float)

# %%
df['Installs'] = df['Installs'].replace('Free',np.nan)

# %%
df['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0', nan],
#       dtype=object)

# %%
sns.distplot(df['Installs'])
# Out:
# <Axes: xlabel='Installs', ylabel='Density'>

# %%
sns.boxplot(df['Installs'])
# Out:
# <Axes: ylabel='Installs'>

# %%
df['Installs']=df['Installs'].astype(float)

# %%
install_median = df['Installs'].median()

# %%
df['Installs'] = df['Installs'].fillna(install_median)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size    Installs  Type  Price Content Rating  \
# 0      159  19456.0     10000.0  Free    0.0       Everyone
# 1      967  14336.0    500000.0  Free    0.0       Everyone
# 2    87510   8908.8   5000000.0  Free    0.0       Everyone
# 3   215644  25600.0  50000000.0  Free    0.0           Teen
# 4      967   2867.2    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['last_Updated_Month']=df['Last Updated'].str.split(' ').str[0]
df['last_Updated_Day']=df['Last Updated'].str.split(' ').str[1]
df['last_Updated_Day']=df['last_Updated_Day'].str.split(',').str[0]
df['last_Updated_year'] = df['Last Updated'].str.split(',').str[1]

# %%
df['last_Updated_Month'].unique()
# Out:
# array(['January', 'August', 'June', 'March', 'April', 'September', 'July',
#        'October', 'November', 'May', 'December', 'February', '1.0.19'],
#       dtype=object)

# %%
df['last_Updated_Month']	=	df['last_Updated_Month'].replace('1.0.19','October')

# %%
df['last_Updated_year'].unique()
# Out:
# array([' 2018', ' 2017', ' 2014', ' 2016', ' 2015', ' 2013', ' 2012',
#        ' 2011', ' 2010', nan], dtype=object)

# %%
df['last_Updated_year']	=	df['last_Updated_year'].fillna(2019)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size    Installs  Type  Price Content Rating  \
# 0      159  19456.0     10000.0  Free    0.0       Everyone
# 1      967  14336.0    500000.0  Free    0.0       Everyone
# 2    87510   8908.8   5000000.0  Free    0.0       Everyone
# 3   215644  25600.0  50000000.0  Free    0.0           Teen
# 4      967   2867.2    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver last_Updated_Month last_Updated_Day last_Updated_year
# 0  4.0.3 and up            January                7              2018
# 1  4.0.3 and up            January               15              2018
# 2  4.0.3 and up             August                1              2018
# 3    4.2 and up               June                8              2018
# 4    4.4 and up               June               20              2018

# %%
# Column last_Updated_year will be used in data type conversion later
pass

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#          Rating  Reviews     Size    Installs  Type  Price Content Rating  \
# 0      4.100000      159  19456.0     10000.0  Free    0.0       Everyone
# 1      3.900000      967  14336.0    500000.0  Free    0.0       Everyone
# 2      4.700000    87510   8908.8   5000000.0  Free    0.0       Everyone
# 3      4.500000   215644  25600.0  50000000.0  Free    0.0           Teen
# 4      4.300000      967   2867.2    100000.0  Free    0.0       Everyone
# ...         ...      ...      ...         ...   ...    ...            ...
# 10836  4.500000       38  54272.0      5000.0  Free    0.0       Everyone
# 10837  5.000000        4   3686.4       100.0  Free    0.0       Everyone
# 10838  4.193338        3   9728.0      1000.0  Free    0.0       Everyone
# 10839  4.500000      114  13312.0      1000.0  Free    0.0     Mature 17+
# 10840  4.500000   398307  19456.0  10000000.0  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                   1
# 10838                    Medical  January 20, 2017                   1
# 10839          Books & Reference  January 19, 2015  Varies with device
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver last_Updated_Month last_Updated_Day  \
# 0            4.0.3 and up            January                7
# 1            4.0.3 and up            January               15
# 2            4.0.3 and up             August                1
# 3              4.2 and up               June                8
# 4              4.4 and up               June               20
# ...                   ...                ...              ...
# 10836          4.1 and up               July               25
# 10837          4.1 and up               July                6
# 10838          2.2 and up            January               20
# 10839  Varies with device            January               19
# 10840  Varies with device               July               25
#
#       last_Updated_year
# 0                  2018
# 1                  2018
# 2                  2018
# 3                  2018
# 4                  2018
# ...                 ...
# 10836              2017
# 10837              2018
# 10838              2017
# 10839              2015
# 10840              2018
#
# [10841 rows x 16 columns]

# %%
df.dtypes
# Out:
# App                    object
# Category               object
# Rating                float64
# Reviews                 int64
# Size                  float64
# Installs              float64
# Type                   object
# Price                 float64
# Content Rating         object
# Genres                 object
# Last Updated           object
# Current Ver            object
# Android Ver            object
# last_Updated_Month     object
# last_Updated_Day       object
# last_Updated_year      object
# dtype: object

# %%
df['Reviews']	=	df['Reviews'].astype(float)
df['last_Updated_Day']	=	df['last_Updated_Day'].astype(float)
df['last_Updated_year']	=	df['last_Updated_year'].astype(float)

# %%
[columns for columns in df.columns if df[columns].dtypes=='0']
# Out:
# []

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews     Size    Installs  Type  Price Content Rating  \
# 0     159.0  19456.0     10000.0  Free    0.0       Everyone
# 1     967.0  14336.0    500000.0  Free    0.0       Everyone
# 2   87510.0   8908.8   5000000.0  Free    0.0       Everyone
# 3  215644.0  25600.0  50000000.0  Free    0.0           Teen
# 4     967.0   2867.2    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver last_Updated_Month  last_Updated_Day  last_Updated_year
# 0  4.0.3 and up            January               7.0             2018.0
# 1  4.0.3 and up            January              15.0             2018.0
# 2  4.0.3 and up             August               1.0             2018.0
# 3    4.2 and up               June               8.0             2018.0
# 4    4.4 and up               June              20.0             2018.0

# %%
df.isnull().sum()
# Out:
# App                   1
# Category              0
# Rating                0
# Reviews               0
# Size                  0
# Installs              0
# Type                  1
# Price                 0
# Content Rating        1
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           3
# last_Updated_Month    0
# last_Updated_Day      1
# last_Updated_year     0
# dtype: int64

# %%
df['Type'] =df['Type'].fillna(df['Type'].mode().iloc[0])

# %%
df[df['Content Rating'].isnull()]
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1000.0  100000.0    0    0.0            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver last_Updated_Month  \
# 10472       1.0.19  4.0 and up         NaN            October
#
#        last_Updated_Day  last_Updated_year
# 10472               NaN             2019.0

# %%
df['Content Rating']	=	df['Content Rating'].fillna(df['Content Rating'].mode().iloc[0])

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                    App             Category    Rating  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN  3.200000
# 1553              Market Update Helper   LIBRARIES_AND_DEMO  4.100000
# 6322            Virtual DJ Sound Mixer                TOOLS  4.200000
# 6803                         BT Master               FAMILY  4.193338
# 7333                       Dots puzzle               FAMILY  4.000000
# 7407                   Calculate My IQ               FAMILY  4.193338
# 7730                            UFO-CQ                TOOLS  4.193338
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE  4.193338
#
#        Reviews     Size   Installs  Type  Price Content Rating  \
# 15        55.0   2764.8     5000.0  Free   0.00       Everyone
# 1553   20145.0     11.0  1000000.0  Free   0.00       Everyone
# 6322    4010.0   8908.8   500000.0  Free   0.00       Everyone
# 6803       0.0    222.0      100.0  Free   0.00       Everyone
# 7333     179.0  14336.0    50000.0  Paid   0.99       Everyone
# 7407      44.0   7372.8    10000.0  Free   0.00       Everyone
# 7730       1.0    237.0       10.0  Paid   0.99       Everyone
# 10342      8.0    658.0     1000.0  Free   0.00       Everyone
#
#                   Genres       Last Updated Current Ver Android Ver
# 15          Art & Design       June 6, 2018         NaN  4.2 and up
# 1553    Libraries & Demo  February 12, 2013         NaN  1.5 and up
# 6322               Tools       May 10, 2017         NaN  4.0 and up
# 6803           Education   November 6, 2016         NaN  1.6 and up
# 7333              Puzzle     April 18, 2018         NaN  4.0 and up
# 7407       Entertainment      April 3, 2017         NaN  2.3 and up
# 7730               Tools       July 4, 2016         NaN  2.0 and up
# 10342  Books & Reference   January 31, 2017         NaN  3.0 and up

# %%
df['Currrent Ver'] = df['Current Ver'].fillna(1)
df['Android Ver']	=	df['Android Ver'].fillna(df['Android Ver'].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# App               1
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# Currrent Ver      0
# dtype: int64

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size              float64
# Installs          float64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# Currrent Ver       object
# dtype: object

# %%
df['last_Updated_Month'] = df['last_Updated_Month'].map({
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
})

# %%
df['last_Updated_Month'].unique()
# Out:
# array([ 1,  8,  6,  3,  4,  9,  7, 10, 11,  5, 12,  2])

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size              float64
# Installs          float64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# Currrent Ver       object
# dtype: object

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews     Size    Installs  Type  Price Content Rating  \
# 0     159.0  19456.0     10000.0  Free    0.0       Everyone
# 1     967.0  14336.0    500000.0  Free    0.0       Everyone
# 2   87510.0   8908.8   5000000.0  Free    0.0       Everyone
# 3  215644.0  25600.0  50000000.0  Free    0.0           Teen
# 4     967.0   2867.2    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver        Currrent Ver
# 0  4.0.3 and up               1.0.0
# 1  4.0.3 and up               2.0.0
# 2  4.0.3 and up               1.2.4
# 3    4.2 and up  Varies with device
# 4    4.4 and up                 1.1

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', '0'], dtype=object)

# %%
df['Type'] = df['Type'].replace('0', 'Free')

# %%
df['Type'] = encoder.fit_transform(df['Type'])

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %%
numeric_features	=	[feature	for	feature	in	df.columns	if	df[feature].dtype	!=	'O']
categorical_features	=	[feature	for	feature	in	df.columns	if	df[feature].dtype	==	'O']
#	print	columns
print('We	have	{}	numerical	features	:	{}'.format(len(numeric_features),	numeric_features))
print('\nWe	have	{}	categorical	features	:	{}'.format(len(categorical_features),	categorical_features))
# Out:
# We	have	8	numerical	features	:	['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'last_Updated_Month', 'last_Updated_Day', 'last_Updated_year']
#
# We	have	9	categorical	features	:	['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver', 'Currrent Ver']

# %%
df[numeric_features].corr()
# Out:
#                       Rating   Reviews      Size  Installs     Price  \
# Rating              1.000000  0.067523  0.057965  0.048529 -0.019519
# Reviews             0.067523  1.000000  0.103946  0.643084 -0.009672
# Size                0.057965  0.103946  1.000000  0.047706 -0.019366
# Installs            0.048529  0.643084  0.047706  1.000000 -0.011688
# Price              -0.019519 -0.009672 -0.019366 -0.011688  1.000000
# last_Updated_Month  0.018724  0.046036  0.028475  0.056419  0.006934
# last_Updated_Day   -0.011732 -0.030141 -0.003671 -0.053122 -0.008225
# last_Updated_year   0.126823  0.075644  0.181829  0.089335 -0.007905
#
#                     last_Updated_Month  last_Updated_Day  last_Updated_year
# Rating                        0.018724         -0.011732           0.126823
# Reviews                       0.046036         -0.030141           0.075644
# Size                          0.028475         -0.003671           0.181829
# Installs                      0.056419         -0.053122           0.089335
# Price                         0.006934         -0.008225          -0.007905
# last_Updated_Month            1.000000         -0.079856          -0.187085
# last_Updated_Day             -0.079856          1.000000          -0.016433
# last_Updated_year            -0.187085         -0.016433           1.000000

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_features[i]], shade=True, color='r')
    plt.xlabel(numeric_features[i])

plt.tight_layout()

# %% [markdown]
# ## Observations
# * Rating and Year is left skewed while Reviews,Size,Installs and Price are right skewed

# %% [markdown]
# ## Create a boxplot to compare rating by Categorie

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.boxplot(x='Category', y='Rating', data=df)
plt.xlabel('Category')
plt.ylabel('Rating')
plt.xticks(rotation=90)  # Rotate x-axis labels by 45 degrees
plt.title('Rating of app od different category')
plt.show()

# %% [markdown]
# ## The relationship between the size of an app and its rating

# %%
plt.figure(figsize=(8, 6))  # Set the figure size
plt.scatter(df['Size'], df['Rating'], color='blue', alpha=0.7)  # 'alpha' controls point transparency
plt.title('Scatter Plot of App Size vs. Rating')
plt.xlabel('App Size (KB)')
plt.ylabel('App Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Observation
#  * We clearly see that as the size increases the rating of app is also ikncreasin

# %% [markdown]
# ## How does the type of app affect its price

# %%
# Create the bar chart
plt.figure(figsize=(10, 6))  # Set the figure size (adjust as needed)
plt.bar(df['Type'], df['Price'], color='skyblue')
plt.title('Prices by App Type')
plt.xlabel('App Type')
plt.ylabel(' Price') 
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a horizontal grid for reference
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.tight_layout()  # Ensure the labels fit within the plot area
plt.show()

# %% [markdown]
# ## Observation
#  * Free apps have No price

# %% [markdown]
# ## The top 10 most popular apps in the dataset

# %%
# Sort the DataFrame by the 'Installs' column in descending order
df_sorted = df.sort_values(by='Installs', ascending=False)

# Display the top 10 apps with the highest number of installs
top_10_apps = df_sorted[['App','Installs']].head(10) # Display the top 10 apps

# Reset the index to default values and drop the current index
top_10_apps = top_10_apps.reset_index(drop=True)

print(top_10_apps)
# Out:
#                                           App      Installs
# 0                           Google Play Games  1.000000e+09
# 1                               Google Photos  1.000000e+09
# 2                               Google Photos  1.000000e+09
# 3                               Google Photos  1.000000e+09
# 4                                Google Drive  1.000000e+09
# 5               Skype - free IM & video calls  1.000000e+09
# 6  Messenger â€“ Text and Video Chat for Free  1.000000e+09
# 7                                     Google+  1.000000e+09
# 8                                      Google  1.000000e+09
# 9                                    Hangouts  1.000000e+09

# %% [markdown]
# ## Observation
# * Above are the Top 10 most installs app

# %% [markdown]
# ## Identify the most popular app categories

# %%
# Category Analysis
category_counts = df['Category'].value_counts()
# Create a bar chart to visualize the distribution of apps across categories
plt.figure(figsize=(12, 6))
plt.bar(category_counts.index, category_counts.values, color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Number of Apps')
plt.title('Number of Apps in Each Category')
plt.tight_layout()
plt.show()

# Install Analysis
install_counts = df.groupby('Category')['Installs'].sum().sort_values(ascending=False)
# Create a bar chart to visualize the total installs in each category
plt.figure(figsize=(12, 6))
plt.bar(install_counts.index, install_counts.values, color='green')
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Total Installs')
plt.title('Total Installs in Each Category')
plt.tight_layout()
plt.show()

# Identify the most popular category based on total installs
most_popular_category = install_counts.idxmax()
print(f"The most popular app category is '{most_popular_category}'")
# Out:
# The most popular app category is 'GAME'

# %% [markdown]
# ## The most popular app category is 'GAME'

# %% [markdown]
# ## identify the best time to launch a new app

# %%
# Extract relevant columns for analysis
launch_data = df[['last_Updated_Month', 'last_Updated_Day', 'last_Updated_year', 'Installs', 'Rating', 'Reviews']]

# Time Series Analysis: Average Installs, Ratings, and Reviews over Time
monthly_avg_installs = launch_data.groupby('last_Updated_Month')['Installs'].mean()
monthly_avg_ratings = launch_data.groupby('last_Updated_Month')['Rating'].mean()
monthly_avg_reviews = launch_data.groupby('last_Updated_Month')['Reviews'].mean()

# Time Series Plots
plt.figure(figsize=(12, 6))
plt.subplot(311)
monthly_avg_installs.plot(kind='line', marker='o', color='skyblue')
plt.title('Average Installs Over Months')
plt.xlabel('Month')
plt.ylabel('Average Installs')

plt.subplot(312)
monthly_avg_ratings.plot(kind='line', marker='o', color='orange')
plt.title('Average Ratings Over Months')
plt.xlabel('Month')
plt.ylabel('Average Rating')

plt.subplot(313)
monthly_avg_reviews.plot(kind='line', marker='o', color='purple')
plt.title('Average Reviews Over Months')
plt.xlabel('Month')
plt.ylabel('Average Reviews')

plt.tight_layout()
plt.show()

# Bar Chart: Number of App Launches by Month
launches_by_month = launch_data['last_Updated_Month'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
launches_by_month.plot(kind='bar', color='green')
plt.title('Number of App Launches by Month')
plt.xlabel('Month')
plt.ylabel('Number of App Launches')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## best time to launch app is july.Most of the apps launched in july

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
df['Category'].value_counts().plot.pie(y=df['Category'],figsize=(15,16),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Observations
# 1. There are more kinds of apps in playstore which are under category of family, games & tools
#  2. Beatuty,comics,arts and weather kinds of apps are very less in playstore

# %%
## Top 10 App Categories
category = pd.DataFrame(df['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
category
# Out:
#                      count
# Category
# FAMILY                1972
# GAME                  1144
# TOOLS                  843
# MEDICAL                463
# BUSINESS               460
# PRODUCTIVITY           424
# PERSONALIZATION        392
# COMMUNICATION          387
# SPORTS                 384
# LIFESTYLE              382
# FINANCE                366
# HEALTH_AND_FITNESS     341
# PHOTOGRAPHY            335
# SOCIAL                 295
# NEWS_AND_MAGAZINES     283
# SHOPPING               260
# TRAVEL_AND_LOCAL       258
# DATING                 234
# BOOKS_AND_REFERENCE    231
# VIDEO_PLAYERS          175
# EDUCATION              156
# ENTERTAINMENT          149
# MAPS_AND_NAVIGATION    137
# FOOD_AND_DRINK         127
# HOUSE_AND_HOME          88
# AUTO_AND_VEHICLES       85
# LIBRARIES_AND_DEMO      85
# WEATHER                 82
# ART_AND_DESIGN          65
# EVENTS                  64
# PARENTING               60
# COMICS                  60
# BEAUTY                  53
# 1.9                      1

# %% [markdown]
# ## Insights
# 1.Family category has the most number of apps with 18% of apps belonging to it, followed by Games category which has 11% of the apps.
# 2.Least number of apps belong to the Beauty category with less than 1% of the total apps belonging to it.

# %% [markdown]
# ## Which Category has largest number of installations??

# %%
df_cat_installs = df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()
df_cat_installs.Installs = df_cat_installs.Installs/1000000000# converting into billions
df2 = df_cat_installs.head(10)
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")
ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %% [markdown]
# ## App with largest size

# %%
df['Size'].max()
# Out:
# np.float64(102400.0)

# %%
102400.0
df_largest_size = df.groupby(['App'])['Size'].sum().sort_values(ascending = False).reset_index()
df_largest_size.Size = df_largest_size.Size/1024# converting into MB
df2 = df_largest_size.head(10)
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")
ax = sns.barplot(x = 'Size' , y = 'App' , data = df2 )
ax.set_xlabel('Size in MB')
ax.set_ylabel('')
ax.set_title("App with large Size", size = 20)
# Out:
# Text(0.5, 1.0, 'App with large Size')

# %% [markdown]
# ## Observation
# ROBOLOX app have the Largest Size
